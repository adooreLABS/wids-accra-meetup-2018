# %% [markdown]
# ### Data Cleaning

# %%
# Import Libraries 
import numpy as np
import pandas as pd
import os

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %pwd # checks on working directory
# Out:
# '/Users/pmaddo/Documents/Collaboration/Intro to Python R for Data Statistis and Data Science- WiDS'

# %%
# Load data 
data = pd.read_csv("dataset/diabetic.csv", sep=',')

# %%
data.columns #get column names 
data.shape #dimension of data
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')
# (10000, 50)

# %%
data.info() # Check structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
# encounter_id                10000 non-null int64
# patient_nbr                 10000 non-null int64
# race                        10000 non-null object
# gender                      10000 non-null object
# age                         10000 non-null object
# weight                      10000 non-null object
# admission_type_id           10000 non-null int64
# discharge_disposition_id    10000 non-null int64
# admission_source_id         10000 non-null int64
# time_in_hospital            10000 non-null int64
# payer_code                  10000 non-null object
# medical_specialty           10000 non-null object
# num_lab_procedures          10000 non-null int64
# num_procedures              10000 non-null int64
# num_medications             10000 non-null int64
# number_outpatient           10000 non-null int64
# number_emergency            10000 non-null int64
# number_inpatient            10000 non-null int64
# diag_1                      10000 non-null object
# diag_2                      10000 non-null object
# diag_3                      10000 non-null object
# number_diagnoses            10000 non-null int64
# max_glu_serum               10000 non-null object
# A1Cresult                   10000 non-null object
# metformin                   10000 non-null object
# repaglinide                 10000 non-null object
# nateglinide                 10000 non-null object
# chlorpropamide              10000 non-null object
# glimepiride                 10000 non-null object
# acetohexamide               10000 non-null object
# glipizide                   10000 non-null object
# glyburide                   10000 non-null object
# tolbutamide                 10000 non-null object
# pioglitazone                10000 non-null object
# rosiglitazone               10000 non-null object
# acarbose                    10000 non-null object
# miglitol                    10000 non-null object
# troglitazone                10000 non-null object
# tolazamide                  10000 non-null object
# examide                     10000 non-null object
# citoglipton                 10000 non-null object
# insulin                     10000 non-null object
# glyburide-metformin         10000 non-null object
# glipizide-metformin         10000 non-null object
# glimepiride-pioglitazone    10000 non-null object
# metformin-rosiglitazone     10000 non-null object
# metformin-pioglitazone      10000 non-null object
# change                      10000 non-null object
# diabetesMed                 10000 non-null object
# readmitted                  10000 non-null object
# dtypes: int64(13), object(37)
# memory usage: 3.8+ MB

# %%
data.head() # display first 6 rows 
data.tail() # display tail o
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 0                 1    ...              No      No                   No
# 1                 3    ...              No      Up                   No
# 2                 2    ...              No      No                   No
# 3                 2    ...              No      Up                   No
# 4                 1    ...              No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]
#       encounter_id  patient_nbr       race  gender      age weight  \
# 9995      42801564     25911072  Caucasian  Female  [80-90)      ?
# 9996      42802962     19316196  Caucasian  Female  [80-90)      ?
# 9997      42805614     19316448  Caucasian    Male  [50-60)      ?
# 9998      42808980       987381  Caucasian  Female  [50-60)      ?
# 9999      42809670     23724657  Caucasian    Male  [80-90)      ?
#
#       admission_type_id  discharge_disposition_id  admission_source_id  \
# 9995                  5                         3                   17
# 9996                  2                        18                    1
# 9997                  1                        18                    7
# 9998                  1                         1                    7
# 9999                  1                         3                   17
#
#       time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 9995                 3    ...              No  Steady                   No
# 9996                 4    ...              No      No                   No
# 9997                14    ...              No      No                   No
# 9998                 2    ...              No      No                   No
# 9999                 4    ...              No      No                   No
#
#       glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 9995                   No                        No                       No
# 9996                   No                        No                       No
# 9997                   No                        No                       No
# 9998                   No                        No                       No
# 9999                   No                        No                       No
#
#       metformin-pioglitazone  change diabetesMed readmitted
# 9995                      No      No         Yes        >30
# 9996                      No      No          No        >30
# 9997                      No      No          No         NO
# 9998                      No      No          No         NO
# 9999                      No      No         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# The data set contains cells with entry "?", which corresponds to missing data. As such, we will replace "?" with NaN for python to easily interpret as missing values

# %%
data=data.replace('?', np.nan) # Replace ? by NaN

# %%
data.iloc[:3]  # Extract first three rows
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
#
#    time_in_hospital    ...      citoglipton insulin  glyburide-metformin  \
# 0                 1    ...               No      No                   No
# 1                 3    ...               No      Up                   No
# 2                 2    ...               No      No                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
#
# [3 rows x 50 columns]

# %%
data.isnull().sum() # check for missing values
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                          184
# gender                          0
# age                             0
# weight                       9725
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  10000
# medical_specialty            3629
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                          6
# diag_2                         63
# diag_3                        300
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
#Check Class distribution 
readmitted_counts = data.groupby('readmitted').size()
print(readmitted_counts)
# Out:
# readmitted
# <30    1098
# >30    3834
# NO     5068
# dtype: int64

# %% [markdown]
# Data is ready for EDA

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Model Building and Evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Splitting the Data

# %%
x_train, x_val, y_train, y_val = train_test_split(X,y)

# %% [markdown]
# ### Building a Logistic Regresison Model

# %%
lr_model = LogisticRegression()
lr_model.fit_transform(x_train, y_train)

lr_predicted_values = lr_model.predit(x_val)

lr_accuracy = accuracy_score(y_val, lr_predicted_values)

# %% [markdown]
# ### Building a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit_transform(x_train, y_train)

tree_predicted_values = tree_model.predict(x_val)

tree_accuracy = model.accuracy_score(y_val, tree_predicted_values)
